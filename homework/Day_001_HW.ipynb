# %% [markdown]
# <h1>作業一</h1>
# data:
# Polynomial Regression
# Use a quadratic function to fit the provided dataset.
#
#
# <h3>
# <li>Q1 你選的這組資料為何重要？：</li>
# <ul>這是對初學者很好的範例</ul>
# <li>Q2 資料從何而?:</li>
# <ul>教授的課堂作業</ul>
# <li>Q3 蒐集而來的資料型態為何?:</li>
# <ul>float</ul>
# <li>Q4 這組資料想解決的問題如何評估?:</li>
# <ul>回歸分析</ul>
#
# </h3>
#
# <h1>作業二</h1>
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：<br>
# <h3>
#
# <li>Q1 核心問題為何？：</li>
# <ul>假設駕駛服務反饋與載客業績有正相關</ul>
# <ul>假設時間與區域跟載客業績有正相關</ul>
# <li>Q2 資料從何而來？：</li>
# <ul>客戶反饋</ul>
# <ul>載客紀錄</ul>
# <li>Q3 蒐集而來的資料型態為何？：</li>
# <ul>text</ul>
# <ul>datetime</ul>
# <ul>int</ul>
#
# <li>Q4 你要回答的問題，其如何評估？：</li>
# <ul>觀察駕駛平均獲得客戶評價之分數與其業績之相關程度</ul>
# <ul>觀察不同區域時間區間之載客業績</ul>
#
# </h3>
# <h1>作業三：</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt

w = 3
b = 0.5

# %%
x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 10.918

# %% [markdown]
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
def MeanSquareError(y,yh):
    return ((y-yh)**2).mean()

mse=MeanSquareError(y, y_hat)
print("The Mean Square Error is %.3f" % (mse))
# Out:
# The Mean Square Error is 202.045
